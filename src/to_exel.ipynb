# %%
import os
import pandas as pd
import pickle as pkl
import numpy as np

# For 10 fold CV
# col = ["Task", "Metrics", "Rhythm", "Fold-1", "Fold-2", "Fold-3", "Fold-4", "Fold-5", "Fold-6", "Fold-7", "Fold-8", "Fold-9", "Fold-10", "Average", "Std"]

# For 8 fold CV
col = ["Task", "Metrics", "Rhythm", "Fold-1", "Fold-2", "Fold-3", "Fold-4", "Fold-5", "Fold-6", "Fold-7", "Fold-8", "Average", "Std"]

# save_file = './results_k-foldCV_unseen_trials.csv'
save_file = './results_10-foldCV_unseen_subjects.csv'
# read_path = '/DEAP_k-foldCV_unseen_trials_results'#
read_path = '/DEAP_10-foldCV_unseen_subjects_results'

try:
    df = pd.read_csv(save_file)
except:
    df = pd.DataFrame(columns=col)

emotions = ['arousal', 'dominance', 'valence']
bands = ['delta', 'theta', 'alpha', 'beta', 'gamma', 'all']

for e in emotions:
    for b in bands:
        filename = f'./eeg_data{read_path}/DEAP_{e}_{b}.pkl'
        if os.path.exists(filename):
            with open(filename, 'rb') as f:
                res = pkl.load(f)
            acc = np.array(res['accuracy'])[:,1]
            values = np.concatenate(([e, 'Accuracy', b], acc, [np.average(acc), np.std(acc)]), axis=0)
            new_row = dict(zip(col, values))
            df = df.append(new_row, ignore_index=True)

df.to_csv(save_file, index=False)

# %%
df.tail()
# Out:
#         Task   Metrics Rhythm               Fold-1               Fold-2  \
# 0    arousal  Accuracy   beta  0.48750001192092896   0.5062500238418579
# 1  dominance  Accuracy   beta   0.5002315044403076   0.5175926089286804
# 2    valence  Accuracy   beta   0.5074074268341064  0.49004629254341125
#
#                 Fold-3              Fold-4              Fold-5  \
# 0  0.49074074625968933   0.510879635810852  0.5009258985519409
# 1   0.5094907283782959  0.5046296119689941  0.5164352059364319
# 2   0.5074074268341064  0.5136573910713196  0.4895833432674408
#
#                 Fold-6               Fold-7               Fold-8  \
# 0   0.4962962865829468   0.5076388716697693  0.49004629254341125
# 1  0.49328702688217163  0.44212964177131653   0.5083333253860474
# 2   0.5018518567085266   0.5131944417953491   0.5069444179534912
#
#                Average                   Std
# 0  0.49878472089767456  0.008363618853068713
# 1   0.4990162067115307  0.022767632170587648
# 2   0.5037615746259689   0.00877780841123111
