# %% [markdown]
# # DEAP

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Activation, AvgPool1D, Dense, Conv1D, Flatten, Dropout, Input, BatchNormalization, GlobalMaxPool1D, MaxPool1D, SpatialDropout1D, GlobalAvgPool1D
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils
from sklearn.preprocessing import StandardScaler                                                      
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix 
from scipy import signal
import pickle as pkl
import gc

# %%
sampling_rate = 128
window_size = 1280
overlap = 256
channel_len = 32
classes=2

bands = {'delta': [0.5/(sampling_rate/2), 4/(sampling_rate/2)], 'theta': [4/(sampling_rate/2), 8/(sampling_rate/2)], \
         'alpha': [8/(sampling_rate/2), 14/(sampling_rate/2)], 'beta': [14/(sampling_rate/2), 30/(sampling_rate/2)], \
         'gamma': [30/(sampling_rate/2), 50/(sampling_rate/2)], 'all': [0.5/(sampling_rate/2), 50/(sampling_rate/2)]} # FIXED: 75 -> 50

# %% [markdown]
# ## Loading Data

# %%
def load_data(eeg_band = None):

  eeg_signal = []
  valence = []
  arousal = []
  dominance = []
  subject = {} # FIXED: Add subject dict

  for i in range(32):
    subject[i] = "{0:02d}".format(i+1)

  for person in range(32):
    print('Person No.' + str(person))
    
    # EEG files address
    address = './eeg_data/DEAP/s'+subject[person]+'.dat'

    with open(address, 'rb') as file:
      data = pkl.load(file, encoding = 'latin1')

    eeg = data['data']
    label = data['labels']
    
    # Assigning classes
    label[label<5.5] = 0
    label[label>=5.5] = 1     

    val = label.T[0] # Valence label
    aro = label.T[1] # Arousal label
    dom = label.T[2] # Dominance label

    del data, label
    

    for i in range(40): # Iterating through 40 vidoes/trials

      sig = eeg[i].T
      v = val[i]
      a = aro[i]
      d = dom[i]

      sig = sig[:, :32] # Considering all 32 EEG channels
      
      num, den = signal.butter(4, bands[eeg_band], 'band') # Butterworth filter of order N = 4
      band_signal = signal.filtfilt(num, den, sig, axis=0)
      sig = band_signal
      del band_signal, num, den
      
      scaler = StandardScaler().fit(sig)
      scaled_sig = scaler.transform(sig)

      del sig
        
      # Segmenting into 10 seconds (1280 timesteps) windows with 2 seconds (256 timesteps) overlap
      start = 0
      while start + window_size < scaled_sig.shape[0]:
        eeg_signal.append(scaled_sig[start:start+window_size, :])

        valence.append(v)
        arousal.append(a)
        dominance.append(d)
        start += window_size - overlap # NOTE: Isn't 'window_size - overlap' right?

      del scaled_sig


  eeg_signal = np.asarray(eeg_signal, dtype = np.float32) # Using 32 bit floating point value to save memory
  valence = np.asarray(valence, dtype = np.int8)
  arousal = np.asarray(arousal, dtype = np.int8)
  dominance = np.asarray(dominance, dtype = np.int8)

  print(valence.shape, valence[valence == 0].shape, valence[valence == 1].shape)
  print(arousal.shape, arousal[arousal == 0].shape, arousal[arousal == 1].shape)
  print(dominance.shape, dominance[dominance == 0].shape, dominance[dominance == 1].shape)

  valence = np_utils.to_categorical(valence)
  arousal = np_utils.to_categorical(arousal)
  dominance = np_utils.to_categorical(dominance)

    
  return (eeg_signal, valence, arousal, dominance)

# %%
FOLD = 1
eeg_band = 'all'#'gamma' # EEG band name

data, valence, arousal, dominance = load_data(eeg_band) # Loading processed data

nb_samples = data.shape[0] # Number of samples
factor = nb_samples//FOLD # Kth fold by this factor
factor_ho = 7*nb_samples//10

shuffler = np.random.permutation(nb_samples) # Shuffling data

data = data[shuffler]
valence = valence[shuffler]
arousal = arousal[shuffler]
dominance = dominance[shuffler]
# Out:
# Person No.0
# Person No.1
# Person No.2
# Person No.3
# Person No.4
# Person No.5
# Person No.6
# Person No.7
# Person No.8
# Person No.9
# Person No.10
# Person No.11
# Person No.12
# Person No.13
# Person No.14
# Person No.15
# Person No.16
# Person No.17
# Person No.18
# Person No.19
# Person No.20
# Person No.21
# Person No.22
# Person No.23
# Person No.24
# Person No.25
# Person No.26
# Person No.27
# Person No.28
# Person No.29
# Person No.30
# Person No.31
# (8960,) (4851,) (4109,)
# (8960,) (4606,) (4354,)
# (8960,) (4599,) (4361,)

# %% [markdown]
# ## CNN Model

# %%
eeg_input = Input(shape = (window_size, channel_len), name='eeg_input') # Input layer

# CNN model
def get_CNN_design():
  x = Conv1D(filters = 32, kernel_size = 1, strides = 2, padding = 'valid', activation='relu', name='conv1')(eeg_input)
  x = Conv1D(filters = 32, kernel_size = 5, strides = 2, padding = 'valid', activation='relu', name='conv2')(x)
  x = AvgPool1D(pool_size=2, name='avg_pool1')(x)
  x = BatchNormalization(name='batch_norm1')(x)
  x = SpatialDropout1D(rate=0.0625, name = 'spatial_dropout1')(x)
  x = Conv1D(filters = 64, kernel_size = 5, strides = 2, padding = 'valid', activation='relu', name='conv3')(x)
  x = Conv1D(filters = 64, kernel_size = 5, strides = 2, padding = 'valid', activation='relu', name='conv4')(x)
  x = AvgPool1D(pool_size=2, name='avg_pool2')(x)
  x = BatchNormalization(name='batch_norm2')(x)
  x = SpatialDropout1D(rate=0.125, name = 'spatial_dropout2')(x)
  x = Conv1D(filters = 128, kernel_size = 3, strides = 1, padding = 'valid', activation='relu', name='conv5')(x)
  x = Conv1D(filters = 128, kernel_size = 3, strides = 1, padding = 'valid', activation='relu', name='conv6')(x)
  x = AvgPool1D(pool_size=2, name='avg_pool3')(x)
  x = BatchNormalization(name='batch_norm3')(x)
  x = SpatialDropout1D(rate=0.25, name = 'spatial_dropout3')(x)
  x = Conv1D(filters = 256, kernel_size = 3, strides = 1, padding = 'valid', activation='relu', name='conv7')(x)
  x = Conv1D(filters = 256, kernel_size = 3, strides = 1, padding = 'valid', activation='relu', name='conv8')(x)
  x = GlobalAvgPool1D(name='global_pool1')(x)
  x = BatchNormalization(name='batch_norm4')(x)
  x = Dropout(0.2)(x)
  x = Dense(64)(x)
  x = Activation('tanh')(x)
  x = Dense(8)(x)
  x = Activation('tanh')(x)
  x = Dropout(0.1)(x)
  return x

def get_model():
  x = get_CNN_design()

  out = Dense(classes, activation='softmax', name = 'output')(x) # Output layer

  model = Model(inputs=eeg_input, outputs=out) # Creating a model instance
  
  adam = Adam(lr=1e-3,decay=1e-5) # Adam optimizer
  
  model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['categorical_accuracy']) # Compiling model
  model.summary()
  
  return model

# %% [markdown]
# ## Training

# %% [markdown]
# ### Valence

# %%
val_res = {'accuracy': [], 'confusion_matrix': []}

gc.collect() # Garbage collecter
for i in range(FOLD):
  print('Fold: '+str(i))

  X_train = data[0 : factor_ho] # Training data
  X_test = data[factor_ho : nb_samples] # Testing data
  val_train = valence[0 : factor_ho] # Valence training labels
  val_test = valence[factor_ho : nb_samples] # Valence testing labels

  gc.collect() # Garbage collecter
  model = get_model()
  model.fit(X_train, val_train, epochs = 100, batch_size = 1024, shuffle = True)

  acc = model.evaluate(X_test, val_test)
  print(acc)

  val_res['accuracy'].append(acc)

  pred = model.predict(X_test)
  val_res['confusion_matrix'].append(confusion_matrix(val_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter


# Dumping valence results
file = './eeg_data/DEAP_valence_' + eeg_band + '.pkl'

with open(file, 'wb') as f:
  pkl.dump(val_res, f)
# Out:
# Fold: 0
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# eeg_input (InputLayer)       [(None, 1280, 32)]        0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 640, 32)           1056
# _________________________________________________________________
# conv2 (Conv1D)               (None, 318, 32)           5152
# _________________________________________________________________
# avg_pool1 (AveragePooling1D) (None, 159, 32)           0
# _________________________________________________________________
# batch_norm1 (BatchNormalizat (None, 159, 32)           128
# _________________________________________________________________
# spatial_dropout1 (SpatialDro (None, 159, 32)           0
# _________________________________________________________________
# conv3 (Conv1D)               (None, 78, 64)            10304
# _________________________________________________________________
# conv4 (Conv1D)               (None, 37, 64)            20544
# _________________________________________________________________
# avg_pool2 (AveragePooling1D) (None, 18, 64)            0
# _________________________________________________________________
# batch_norm2 (BatchNormalizat (None, 18, 64)            256
# _________________________________________________________________
# spatial_dropout2 (SpatialDro (None, 18, 64)            0
# _________________________________________________________________
# conv5 (Conv1D)               (None, 16, 128)           24704
# _________________________________________________________________
# conv6 (Conv1D)               (None, 14, 128)           49280
# _________________________________________________________________
# avg_pool3 (AveragePooling1D) (None, 7, 128)            0
# _________________________________________________________________
# batch_norm3 (BatchNormalizat (None, 7, 128)            512
# _________________________________________________________________
# spatial_dropout3 (SpatialDro (None, 7, 128)            0
# _________________________________________________________________
# conv7 (Conv1D)               (None, 5, 256)            98560
# _________________________________________________________________
# conv8 (Conv1D)               (None, 3, 256)            196864
# _________________________________________________________________
# global_pool1 (GlobalAverageP (None, 256)               0
# _________________________________________________________________
# batch_norm4 (BatchNormalizat (None, 256)               1024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 8)                 520
# _________________________________________________________________
# activation_11 (Activation)   (None, 8)                 0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# output (Dense)               (None, 2)                 18
# =================================================================
# Total params: 425,370
# Trainable params: 424,410
# Non-trainable params: 960
# _________________________________________________________________
# /home/hyojinju/.conda/envs/hyojin_py37_tf25/lib/python3.7/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 7/7 [==============================] - 1s 46ms/step - loss: 0.7764 - categorical_accuracy: 0.5092
# Epoch 2/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.7173 - categorical_accuracy: 0.5421
# Epoch 3/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.7134 - categorical_accuracy: 0.5330
# Epoch 4/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.7028 - categorical_accuracy: 0.5560
# Epoch 5/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6886 - categorical_accuracy: 0.5722
# Epoch 6/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6800 - categorical_accuracy: 0.5824
# Epoch 7/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6765 - categorical_accuracy: 0.5837
# Epoch 8/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6677 - categorical_accuracy: 0.5912
# Epoch 9/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6560 - categorical_accuracy: 0.6052
# Epoch 10/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6433 - categorical_accuracy: 0.6293
# Epoch 11/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.6397 - categorical_accuracy: 0.6280
# Epoch 12/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6242 - categorical_accuracy: 0.6430
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6158 - categorical_accuracy: 0.6497
# Epoch 14/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5981 - categorical_accuracy: 0.6695
# Epoch 15/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5920 - categorical_accuracy: 0.6797
# Epoch 16/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5771 - categorical_accuracy: 0.6902
# Epoch 17/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5667 - categorical_accuracy: 0.7022
# Epoch 18/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5452 - categorical_accuracy: 0.7144
# Epoch 19/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5258 - categorical_accuracy: 0.7349
# Epoch 20/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5127 - categorical_accuracy: 0.7506
# Epoch 21/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4916 - categorical_accuracy: 0.7553
# Epoch 22/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4884 - categorical_accuracy: 0.7634
# Epoch 23/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4665 - categorical_accuracy: 0.7781
# Epoch 24/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4418 - categorical_accuracy: 0.7915
# Epoch 25/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4427 - categorical_accuracy: 0.7974
# Epoch 26/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4092 - categorical_accuracy: 0.8146
# Epoch 27/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4032 - categorical_accuracy: 0.8176
# Epoch 28/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3940 - categorical_accuracy: 0.8249
# Epoch 29/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.3834 - categorical_accuracy: 0.8304
# Epoch 30/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3732 - categorical_accuracy: 0.8359
# Epoch 31/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3533 - categorical_accuracy: 0.8450
# Epoch 32/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3493 - categorical_accuracy: 0.8489
# Epoch 33/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3646 - categorical_accuracy: 0.8409
# Epoch 34/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3348 - categorical_accuracy: 0.8563
# Epoch 35/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3151 - categorical_accuracy: 0.8651
# Epoch 36/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3013 - categorical_accuracy: 0.8740
# Epoch 37/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2977 - categorical_accuracy: 0.8756
# Epoch 38/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2780 - categorical_accuracy: 0.8889
# Epoch 39/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2720 - categorical_accuracy: 0.8895
# Epoch 40/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2643 - categorical_accuracy: 0.8956
# Epoch 41/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2613 - categorical_accuracy: 0.8906
# Epoch 42/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2590 - categorical_accuracy: 0.8916
# Epoch 43/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2583 - categorical_accuracy: 0.8975
# Epoch 44/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2608 - categorical_accuracy: 0.8962
# Epoch 45/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2588 - categorical_accuracy: 0.8968
# Epoch 46/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2603 - categorical_accuracy: 0.8938
# Epoch 47/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2446 - categorical_accuracy: 0.9035
# Epoch 48/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2452 - categorical_accuracy: 0.9027
# Epoch 49/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2398 - categorical_accuracy: 0.9078
# Epoch 50/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2039 - categorical_accuracy: 0.9230
# Epoch 51/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2227 - categorical_accuracy: 0.9112
# Epoch 52/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2222 - categorical_accuracy: 0.9126
# Epoch 53/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2025 - categorical_accuracy: 0.9214
# Epoch 54/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1874 - categorical_accuracy: 0.9278
# Epoch 55/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1899 - categorical_accuracy: 0.9270
# Epoch 56/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1808 - categorical_accuracy: 0.9321
# Epoch 57/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1730 - categorical_accuracy: 0.9337
# Epoch 58/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1731 - categorical_accuracy: 0.9321
# Epoch 59/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1814 - categorical_accuracy: 0.9305
# Epoch 60/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1851 - categorical_accuracy: 0.9289
# Epoch 61/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1748 - categorical_accuracy: 0.9345
# Epoch 62/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1692 - categorical_accuracy: 0.9356
# Epoch 63/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1548 - categorical_accuracy: 0.9455
# Epoch 64/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1656 - categorical_accuracy: 0.9391
# Epoch 65/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1566 - categorical_accuracy: 0.9407
# Epoch 66/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1508 - categorical_accuracy: 0.9440
# Epoch 67/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1494 - categorical_accuracy: 0.9426
# Epoch 68/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1543 - categorical_accuracy: 0.9440
# Epoch 69/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1538 - categorical_accuracy: 0.9428
# Epoch 70/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1399 - categorical_accuracy: 0.9496
# Epoch 71/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1356 - categorical_accuracy: 0.9499
# Epoch 72/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1399 - categorical_accuracy: 0.9506
# Epoch 73/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1495 - categorical_accuracy: 0.9440
# Epoch 74/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1455 - categorical_accuracy: 0.9466
# Epoch 75/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1353 - categorical_accuracy: 0.9480
# Epoch 76/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1456 - categorical_accuracy: 0.9432
# Epoch 77/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1427 - categorical_accuracy: 0.9456
# Epoch 78/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1338 - categorical_accuracy: 0.9528
# Epoch 79/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1388 - categorical_accuracy: 0.9496
# Epoch 80/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1255 - categorical_accuracy: 0.9539
# Epoch 81/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1318 - categorical_accuracy: 0.9526
# Epoch 82/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1180 - categorical_accuracy: 0.9574
# Epoch 83/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1226 - categorical_accuracy: 0.9563
# Epoch 84/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1133 - categorical_accuracy: 0.9585
# Epoch 85/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1159 - categorical_accuracy: 0.9592
# Epoch 86/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1201 - categorical_accuracy: 0.9582
# Epoch 87/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1338 - categorical_accuracy: 0.9498
# Epoch 88/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1489 - categorical_accuracy: 0.9420
# Epoch 89/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1314 - categorical_accuracy: 0.9525
# Epoch 90/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1225 - categorical_accuracy: 0.9570
# Epoch 91/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1146 - categorical_accuracy: 0.9597
# Epoch 92/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1077 - categorical_accuracy: 0.9606
# Epoch 93/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1047 - categorical_accuracy: 0.9638
# Epoch 94/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1017 - categorical_accuracy: 0.9641
# Epoch 95/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1070 - categorical_accuracy: 0.9630
# Epoch 96/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1003 - categorical_accuracy: 0.9648
# Epoch 97/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1044 - categorical_accuracy: 0.9627
# Epoch 98/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1003 - categorical_accuracy: 0.9652
# Epoch 99/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1097 - categorical_accuracy: 0.9608
# Epoch 100/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1069 - categorical_accuracy: 0.9608
# 84/84 [==============================] - 0s 4ms/step - loss: 1.5750 - categorical_accuracy: 0.5398
# [1.5750007629394531, 0.5398065447807312]

# %%
for i in val_res['accuracy']:
  print(round(i[1]*100, 2)) # Rounding off to two decimal places
# Out:
# 53.98

# %%
for i in val_res['confusion_matrix']:
  print(i)
# Out:
# [[829 600]
#  [637 622]]

# %% [markdown]
# ### Arousal

# %%
aro_res = {'accuracy': [], 'confusion_matrix': []}

gc.collect() # Garbage collecter
for i in range(FOLD):
  print('Fold: '+str(i))
  
  X_train = data[0 : factor_ho] # Training data
  X_test = data[factor_ho : nb_samples] # Testing data
  aro_train = arousal[0 : factor_ho] # Valence training labels
  aro_test = arousal[factor_ho : nb_samples] # Valence testing labels

  gc.collect() # Garbage collecter
  model = get_model()
  model.fit(X_train, aro_train, epochs = 100, batch_size = 1024, shuffle = True)

  acc = model.evaluate(X_test, aro_test)
  print(acc)

  aro_res['accuracy'].append(acc)

  pred = model.predict(X_test)
  aro_res['confusion_matrix'].append(confusion_matrix(aro_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter


# Dumping arousal results
file = './eeg_data/DEAP_arousal_' + eeg_band + '.pkl'

with open(file, 'wb') as f:
  pkl.dump(aro_res, f)
# Out:
# Fold: 0
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# eeg_input (InputLayer)       [(None, 1280, 32)]        0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 640, 32)           1056
# _________________________________________________________________
# conv2 (Conv1D)               (None, 318, 32)           5152
# _________________________________________________________________
# avg_pool1 (AveragePooling1D) (None, 159, 32)           0
# _________________________________________________________________
# batch_norm1 (BatchNormalizat (None, 159, 32)           128
# _________________________________________________________________
# spatial_dropout1 (SpatialDro (None, 159, 32)           0
# _________________________________________________________________
# conv3 (Conv1D)               (None, 78, 64)            10304
# _________________________________________________________________
# conv4 (Conv1D)               (None, 37, 64)            20544
# _________________________________________________________________
# avg_pool2 (AveragePooling1D) (None, 18, 64)            0
# _________________________________________________________________
# batch_norm2 (BatchNormalizat (None, 18, 64)            256
# _________________________________________________________________
# spatial_dropout2 (SpatialDro (None, 18, 64)            0
# _________________________________________________________________
# conv5 (Conv1D)               (None, 16, 128)           24704
# _________________________________________________________________
# conv6 (Conv1D)               (None, 14, 128)           49280
# _________________________________________________________________
# avg_pool3 (AveragePooling1D) (None, 7, 128)            0
# _________________________________________________________________
# batch_norm3 (BatchNormalizat (None, 7, 128)            512
# _________________________________________________________________
# spatial_dropout3 (SpatialDro (None, 7, 128)            0
# _________________________________________________________________
# conv7 (Conv1D)               (None, 5, 256)            98560
# _________________________________________________________________
# conv8 (Conv1D)               (None, 3, 256)            196864
# _________________________________________________________________
# global_pool1 (GlobalAverageP (None, 256)               0
# _________________________________________________________________
# batch_norm4 (BatchNormalizat (None, 256)               1024
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                16448
# _________________________________________________________________
# activation_12 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 520
# _________________________________________________________________
# activation_13 (Activation)   (None, 8)                 0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# output (Dense)               (None, 2)                 18
# =================================================================
# Total params: 425,370
# Trainable params: 424,410
# Non-trainable params: 960
# _________________________________________________________________
# /home/hyojinju/.conda/envs/hyojin_py37_tf25/lib/python3.7/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 7/7 [==============================] - 1s 32ms/step - loss: 0.7788 - categorical_accuracy: 0.5043
# Epoch 2/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.7303 - categorical_accuracy: 0.5244
# Epoch 3/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.7076 - categorical_accuracy: 0.5670
# Epoch 4/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.7007 - categorical_accuracy: 0.5749
# Epoch 5/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6872 - categorical_accuracy: 0.5987
# Epoch 6/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6779 - categorical_accuracy: 0.6027
# Epoch 7/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6780 - categorical_accuracy: 0.6137
# Epoch 8/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.6543 - categorical_accuracy: 0.6350
# Epoch 9/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6423 - categorical_accuracy: 0.6429
# Epoch 10/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6305 - categorical_accuracy: 0.6577
# Epoch 11/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6191 - categorical_accuracy: 0.6633
# Epoch 12/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6155 - categorical_accuracy: 0.6644
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6087 - categorical_accuracy: 0.6752
# Epoch 14/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5921 - categorical_accuracy: 0.6816
# Epoch 15/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5711 - categorical_accuracy: 0.7050
# Epoch 16/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5610 - categorical_accuracy: 0.7108
# Epoch 17/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5450 - categorical_accuracy: 0.7277
# Epoch 18/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5413 - categorical_accuracy: 0.7219
# Epoch 19/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5163 - categorical_accuracy: 0.7430
# Epoch 20/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5035 - categorical_accuracy: 0.7570
# Epoch 21/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5028 - categorical_accuracy: 0.7567
# Epoch 22/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4901 - categorical_accuracy: 0.7628
# Epoch 23/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4726 - categorical_accuracy: 0.7760
# Epoch 24/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4542 - categorical_accuracy: 0.7819
# Epoch 25/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4443 - categorical_accuracy: 0.7907
# Epoch 26/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4180 - categorical_accuracy: 0.8114
# Epoch 27/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4020 - categorical_accuracy: 0.8186
# Epoch 28/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3888 - categorical_accuracy: 0.8302
# Epoch 29/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3707 - categorical_accuracy: 0.8388
# Epoch 30/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3658 - categorical_accuracy: 0.8406
# Epoch 31/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3670 - categorical_accuracy: 0.8347
# Epoch 32/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3565 - categorical_accuracy: 0.8468
# Epoch 33/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3510 - categorical_accuracy: 0.8458
# Epoch 34/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3337 - categorical_accuracy: 0.8552
# Epoch 35/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.3241 - categorical_accuracy: 0.8648
# Epoch 36/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3096 - categorical_accuracy: 0.8720
# Epoch 37/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2998 - categorical_accuracy: 0.8758
# Epoch 38/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2842 - categorical_accuracy: 0.8850
# Epoch 39/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2807 - categorical_accuracy: 0.8855
# Epoch 40/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2717 - categorical_accuracy: 0.8897
# Epoch 41/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2857 - categorical_accuracy: 0.8812
# Epoch 42/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2745 - categorical_accuracy: 0.8863
# Epoch 43/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2581 - categorical_accuracy: 0.8937
# Epoch 44/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2562 - categorical_accuracy: 0.8968
# Epoch 45/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2447 - categorical_accuracy: 0.9008
# Epoch 46/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2314 - categorical_accuracy: 0.9066
# Epoch 47/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2396 - categorical_accuracy: 0.9067
# Epoch 48/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2372 - categorical_accuracy: 0.9080
# Epoch 49/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2398 - categorical_accuracy: 0.9029
# Epoch 50/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2346 - categorical_accuracy: 0.9024
# Epoch 51/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2289 - categorical_accuracy: 0.9096
# Epoch 52/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2190 - categorical_accuracy: 0.9137
# Epoch 53/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2113 - categorical_accuracy: 0.9173
# Epoch 54/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2157 - categorical_accuracy: 0.9133
# Epoch 55/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2012 - categorical_accuracy: 0.9236
# Epoch 56/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1897 - categorical_accuracy: 0.9270
# Epoch 57/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1834 - categorical_accuracy: 0.9289
# Epoch 58/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1774 - categorical_accuracy: 0.9335
# Epoch 59/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1783 - categorical_accuracy: 0.9342
# Epoch 60/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1959 - categorical_accuracy: 0.9283
# Epoch 61/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1831 - categorical_accuracy: 0.9298
# Epoch 62/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1816 - categorical_accuracy: 0.9319
# Epoch 63/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1673 - categorical_accuracy: 0.9388
# Epoch 64/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1559 - categorical_accuracy: 0.9434
# Epoch 65/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1539 - categorical_accuracy: 0.9424
# Epoch 66/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1568 - categorical_accuracy: 0.9393
# Epoch 67/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1517 - categorical_accuracy: 0.9426
# Epoch 68/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1452 - categorical_accuracy: 0.9456
# Epoch 69/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1520 - categorical_accuracy: 0.9426
# Epoch 70/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1411 - categorical_accuracy: 0.9483
# Epoch 71/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1560 - categorical_accuracy: 0.9413
# Epoch 72/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1458 - categorical_accuracy: 0.9448
# Epoch 73/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1340 - categorical_accuracy: 0.9523
# Epoch 74/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1494 - categorical_accuracy: 0.9439
# Epoch 75/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1260 - categorical_accuracy: 0.9568
# Epoch 76/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1363 - categorical_accuracy: 0.9493
# Epoch 77/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1291 - categorical_accuracy: 0.9546
# Epoch 78/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1335 - categorical_accuracy: 0.9530
# Epoch 79/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1131 - categorical_accuracy: 0.9574
# Epoch 80/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1206 - categorical_accuracy: 0.9563
# Epoch 81/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1210 - categorical_accuracy: 0.9565
# Epoch 82/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1227 - categorical_accuracy: 0.9574
# Epoch 83/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1218 - categorical_accuracy: 0.9554
# Epoch 84/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1198 - categorical_accuracy: 0.9581
# Epoch 85/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1154 - categorical_accuracy: 0.9589
# Epoch 86/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1131 - categorical_accuracy: 0.9592
# Epoch 87/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1140 - categorical_accuracy: 0.9605
# Epoch 88/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1197 - categorical_accuracy: 0.9573
# Epoch 89/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1122 - categorical_accuracy: 0.9608
# Epoch 90/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1063 - categorical_accuracy: 0.9613
# Epoch 91/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1058 - categorical_accuracy: 0.9625
# Epoch 92/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0999 - categorical_accuracy: 0.9627
# Epoch 93/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1025 - categorical_accuracy: 0.9649
# Epoch 94/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1025 - categorical_accuracy: 0.9622
# Epoch 95/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1009 - categorical_accuracy: 0.9648
# Epoch 96/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1086 - categorical_accuracy: 0.9611
# Epoch 97/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0995 - categorical_accuracy: 0.9649
# Epoch 98/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1027 - categorical_accuracy: 0.9641
# Epoch 99/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1040 - categorical_accuracy: 0.9625
# Epoch 100/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0954 - categorical_accuracy: 0.9652
# 84/84 [==============================] - 0s 4ms/step - loss: 1.4611 - categorical_accuracy: 0.5960
# [1.4610931873321533, 0.5959821343421936]

# %%
for i in aro_res['accuracy']:
  print(round(i[1]*100, 2)) # Rounding off to two decimal places
# Out:
# 59.6

# %%
for i in aro_res['confusion_matrix']:
  print(i)
# Out:
# [[843 554]
#  [532 759]]

# %% [markdown]
# ### Dominance

# %%
dom_res = {'accuracy':[], 'confusion_matrix':[]}

gc.collect() # Garbage collecter
for i in range(FOLD):
  print('Fold: '+str(i))

  X_train = data[0 : factor_ho] # Training data
  X_test = data[factor_ho : nb_samples] # Testing data
  dom_train = dominance[0 : factor_ho] # Valence training labels
  dom_test = dominance[factor_ho : nb_samples] # Valence testing labels

  gc.collect() # Garbage collecter
  model = get_model()
  model.fit(X_train, dom_train, epochs = 100, batch_size = 1024, shuffle = True)

  acc = model.evaluate(X_test, dom_test)
  print(acc)
    
  dom_res['accuracy'].append(acc)

  pred = model.predict(X_test)
  dom_res['confusion_matrix'].append(confusion_matrix(dom_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter


# Dumping dominance results
file = './eeg_data/DEAP_dominance_' + eeg_band + '.pkl'

with open(file, 'wb') as f:
  pkl.dump(dom_res, f)
# Out:
# Fold: 0
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# eeg_input (InputLayer)       [(None, 1280, 32)]        0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 640, 32)           1056
# _________________________________________________________________
# conv2 (Conv1D)               (None, 318, 32)           5152
# _________________________________________________________________
# avg_pool1 (AveragePooling1D) (None, 159, 32)           0
# _________________________________________________________________
# batch_norm1 (BatchNormalizat (None, 159, 32)           128
# _________________________________________________________________
# spatial_dropout1 (SpatialDro (None, 159, 32)           0
# _________________________________________________________________
# conv3 (Conv1D)               (None, 78, 64)            10304
# _________________________________________________________________
# conv4 (Conv1D)               (None, 37, 64)            20544
# _________________________________________________________________
# avg_pool2 (AveragePooling1D) (None, 18, 64)            0
# _________________________________________________________________
# batch_norm2 (BatchNormalizat (None, 18, 64)            256
# _________________________________________________________________
# spatial_dropout2 (SpatialDro (None, 18, 64)            0
# _________________________________________________________________
# conv5 (Conv1D)               (None, 16, 128)           24704
# _________________________________________________________________
# conv6 (Conv1D)               (None, 14, 128)           49280
# _________________________________________________________________
# avg_pool3 (AveragePooling1D) (None, 7, 128)            0
# _________________________________________________________________
# batch_norm3 (BatchNormalizat (None, 7, 128)            512
# _________________________________________________________________
# spatial_dropout3 (SpatialDro (None, 7, 128)            0
# _________________________________________________________________
# conv7 (Conv1D)               (None, 5, 256)            98560
# _________________________________________________________________
# conv8 (Conv1D)               (None, 3, 256)            196864
# _________________________________________________________________
# global_pool1 (GlobalAverageP (None, 256)               0
# _________________________________________________________________
# batch_norm4 (BatchNormalizat (None, 256)               1024
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                16448
# _________________________________________________________________
# activation_14 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 8)                 520
# _________________________________________________________________
# activation_15 (Activation)   (None, 8)                 0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# output (Dense)               (None, 2)                 18
# =================================================================
# Total params: 425,370
# Trainable params: 424,410
# Non-trainable params: 960
# _________________________________________________________________
# /home/hyojinju/.conda/envs/hyojin_py37_tf25/lib/python3.7/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 7/7 [==============================] - 1s 35ms/step - loss: 0.8007 - categorical_accuracy: 0.5153
# Epoch 2/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.7274 - categorical_accuracy: 0.5604
# Epoch 3/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.7049 - categorical_accuracy: 0.5738
# Epoch 4/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6864 - categorical_accuracy: 0.5955
# Epoch 5/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6786 - categorical_accuracy: 0.5961
# Epoch 6/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6634 - categorical_accuracy: 0.6207
# Epoch 7/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6471 - categorical_accuracy: 0.6271
# Epoch 8/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6412 - categorical_accuracy: 0.6325
# Epoch 9/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6242 - categorical_accuracy: 0.6443
# Epoch 10/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6172 - categorical_accuracy: 0.6575
# Epoch 11/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6084 - categorical_accuracy: 0.6663
# Epoch 12/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5977 - categorical_accuracy: 0.6696
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5895 - categorical_accuracy: 0.6814
# Epoch 14/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5662 - categorical_accuracy: 0.7012
# Epoch 15/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.5669 - categorical_accuracy: 0.6988
# Epoch 16/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5516 - categorical_accuracy: 0.7170
# Epoch 17/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5370 - categorical_accuracy: 0.7275
# Epoch 18/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5229 - categorical_accuracy: 0.7384
# Epoch 19/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5159 - categorical_accuracy: 0.7427
# Epoch 20/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4917 - categorical_accuracy: 0.7640
# Epoch 21/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4862 - categorical_accuracy: 0.7669
# Epoch 22/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4665 - categorical_accuracy: 0.7825
# Epoch 23/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4557 - categorical_accuracy: 0.7860
# Epoch 24/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4492 - categorical_accuracy: 0.7900
# Epoch 25/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4427 - categorical_accuracy: 0.7942
# Epoch 26/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4107 - categorical_accuracy: 0.8146
# Epoch 27/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4034 - categorical_accuracy: 0.8186
# Epoch 28/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4065 - categorical_accuracy: 0.8217
# Epoch 29/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3852 - categorical_accuracy: 0.8253
# Epoch 30/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3785 - categorical_accuracy: 0.8356
# Epoch 31/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3608 - categorical_accuracy: 0.8386
# Epoch 32/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3432 - categorical_accuracy: 0.8546
# Epoch 33/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3311 - categorical_accuracy: 0.8600
# Epoch 34/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3187 - categorical_accuracy: 0.8664
# Epoch 35/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3141 - categorical_accuracy: 0.8702
# Epoch 36/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3009 - categorical_accuracy: 0.8748
# Epoch 37/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2862 - categorical_accuracy: 0.8855
# Epoch 38/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2825 - categorical_accuracy: 0.8822
# Epoch 39/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2782 - categorical_accuracy: 0.8874
# Epoch 40/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2775 - categorical_accuracy: 0.8882
# Epoch 41/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2694 - categorical_accuracy: 0.8908
# Epoch 42/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2660 - categorical_accuracy: 0.8949
# Epoch 43/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2589 - categorical_accuracy: 0.8943
# Epoch 44/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2386 - categorical_accuracy: 0.9042
# Epoch 45/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2328 - categorical_accuracy: 0.9115
# Epoch 46/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2112 - categorical_accuracy: 0.9149
# Epoch 47/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2241 - categorical_accuracy: 0.9137
# Epoch 48/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2166 - categorical_accuracy: 0.9174
# Epoch 49/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2164 - categorical_accuracy: 0.9160
# Epoch 50/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2081 - categorical_accuracy: 0.9187
# Epoch 51/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2042 - categorical_accuracy: 0.9198
# Epoch 52/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1888 - categorical_accuracy: 0.9300
# Epoch 53/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1986 - categorical_accuracy: 0.9236
# Epoch 54/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1754 - categorical_accuracy: 0.9318
# Epoch 55/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1846 - categorical_accuracy: 0.9300
# Epoch 56/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1780 - categorical_accuracy: 0.9327
# Epoch 57/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1746 - categorical_accuracy: 0.9353
# Epoch 58/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1744 - categorical_accuracy: 0.9345
# Epoch 59/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1725 - categorical_accuracy: 0.9321
# Epoch 60/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1736 - categorical_accuracy: 0.9369
# Epoch 61/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1720 - categorical_accuracy: 0.9373
# Epoch 62/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1542 - categorical_accuracy: 0.9421
# Epoch 63/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1479 - categorical_accuracy: 0.9464
# Epoch 64/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1606 - categorical_accuracy: 0.9378
# Epoch 65/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1516 - categorical_accuracy: 0.9444
# Epoch 66/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1421 - categorical_accuracy: 0.9483
# Epoch 67/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1366 - categorical_accuracy: 0.9488
# Epoch 68/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1373 - categorical_accuracy: 0.9517
# Epoch 69/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1436 - categorical_accuracy: 0.9480
# Epoch 70/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1542 - categorical_accuracy: 0.9450
# Epoch 71/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1454 - categorical_accuracy: 0.9472
# Epoch 72/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1421 - categorical_accuracy: 0.9475
# Epoch 73/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1322 - categorical_accuracy: 0.9503
# Epoch 74/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1338 - categorical_accuracy: 0.9498
# Epoch 75/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1212 - categorical_accuracy: 0.9562
# Epoch 76/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1220 - categorical_accuracy: 0.9554
# Epoch 77/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1242 - categorical_accuracy: 0.9568
# Epoch 78/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1225 - categorical_accuracy: 0.9538
# Epoch 79/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1257 - categorical_accuracy: 0.9565
# Epoch 80/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1125 - categorical_accuracy: 0.9603
# Epoch 81/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1118 - categorical_accuracy: 0.9606
# Epoch 82/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1128 - categorical_accuracy: 0.9601
# Epoch 83/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1186 - categorical_accuracy: 0.9571
# Epoch 84/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1156 - categorical_accuracy: 0.9571
# Epoch 85/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1071 - categorical_accuracy: 0.9606
# Epoch 86/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1007 - categorical_accuracy: 0.9656
# Epoch 87/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1036 - categorical_accuracy: 0.9630
# Epoch 88/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0873 - categorical_accuracy: 0.9703
# Epoch 89/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1138 - categorical_accuracy: 0.9597
# Epoch 90/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1087 - categorical_accuracy: 0.9622
# Epoch 91/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1011 - categorical_accuracy: 0.9638
# Epoch 92/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0911 - categorical_accuracy: 0.9688
# Epoch 93/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0888 - categorical_accuracy: 0.9684
# Epoch 94/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1076 - categorical_accuracy: 0.9621
# Epoch 95/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1014 - categorical_accuracy: 0.9638
# Epoch 96/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1032 - categorical_accuracy: 0.9617
# Epoch 97/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1063 - categorical_accuracy: 0.9638
# Epoch 98/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0978 - categorical_accuracy: 0.9652
# Epoch 99/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1009 - categorical_accuracy: 0.9630
# Epoch 100/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0994 - categorical_accuracy: 0.9638
# 84/84 [==============================] - 0s 4ms/step - loss: 1.5634 - categorical_accuracy: 0.5740
# [1.5633721351623535, 0.574032723903656]

# %%
for i in dom_res['accuracy']:
  print(round(i[1]*100, 2)) # Rounding off to two decimal places
# Out:
# 57.4

# %%
for i in dom_res['confusion_matrix']:
  print(i)
# Out:
# [[ 436  923]
#  [ 222 1107]]
